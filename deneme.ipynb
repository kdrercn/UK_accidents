# %%
import folium
#we are passing Into Map location coodinates of Tughlakabad,new delhi which we found in avove codes.
#using geopy library
map=folium.Map(location=[51.489096,-0.19117])
map

map=folium.Map(location=[51.489096,-0.19117],zoom_start=10)
map.add_child(folium.Marker(location=[51.489096,-0.19117],popup='X',icon=folium.Icon(color='green')))


map.add_child(folium.Marker(location=[51.520075,-0.211708],popup='X',icon=folium.Icon(color='green')))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9874f346a7a30f732dd9888a53cd78d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9874f346a7a30f732dd9888a53cd78d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9874f346a7a30f732dd9888a53cd78d9 = L.map(
#                 &quot;map_9874f346a7a30f732dd9888a53cd78d9&quot;,
#                 {
#                     center: [51.489096, -0.19117],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73512853327889e36d1aba2ffd3098fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9874f346a7a30f732dd9888a53cd78d9);
#
#
#             var marker_ea15811291865b7f18fd4e0e68b147b8 = L.marker(
#                 [51.489096, -0.19117],
#                 {}
#             ).addTo(map_9874f346a7a30f732dd9888a53cd78d9);
#
#
#             var icon_ddb1077953da144976db2976abd47446 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea15811291865b7f18fd4e0e68b147b8.setIcon(icon_ddb1077953da144976db2976abd47446);
#
#
#         var popup_96d7c97a987a9f09c837d8279bde7a37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4849eaa9bfce22aa2e88faa270f3e889 = $(`&lt;div id=&quot;html_4849eaa9bfce22aa2e88faa270f3e889&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;X&lt;/div&gt;`)[0];
#                 popup_96d7c97a987a9f09c837d8279bde7a37.setContent(html_4849eaa9bfce22aa2e88faa270f3e889);
#
#
#
#         marker_ea15811291865b7f18fd4e0e68b147b8.bindPopup(popup_96d7c97a987a9f09c837d8279bde7a37)
#         ;
#
#
#
#
#             var marker_475da680a1b56e30455b3116796487b1 = L.marker(
#                 [51.520075, -0.211708],
#                 {}
#             ).addTo(map_9874f346a7a30f732dd9888a53cd78d9);
#
#
#             var icon_e864f4dc2380572bcd8aefd46a74ab79 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_475da680a1b56e30455b3116796487b1.setIcon(icon_e864f4dc2380572bcd8aefd46a74ab79);
#
#
#         var popup_4c40911daca2acd3e5e5ee7e65ed8220 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b8f1001a9e4861bb359eb196a1cb609 = $(`&lt;div id=&quot;html_0b8f1001a9e4861bb359eb196a1cb609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;X&lt;/div&gt;`)[0];
#                 popup_4c40911daca2acd3e5e5ee7e65ed8220.setContent(html_0b8f1001a9e4861bb359eb196a1cb609);
#
#
#
#         marker_475da680a1b56e30455b3116796487b1.bindPopup(popup_4c40911daca2acd3e5e5ee7e65ed8220)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
